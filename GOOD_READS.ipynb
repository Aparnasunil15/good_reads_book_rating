# %% [markdown]
# <a href="https://colab.research.google.com/github/Aparnasunil15/good_reads_book_rating/blob/main/GOOD_READS.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# GOOD READS BOOK RATING

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
df=pd.read_csv('/content/Goodreadss Books.csv')
df
# Out:
#        Unnamed: 0  bookId                                      title  \
# 0               0       1     Harry Potter and the Half-Blood Prince
# 1               1       2  Harry Potter and the Order of the Phoenix
# 2               2       3      Harry Potter and the Sorcerer's Stone
# 3               3       4    Harry Potter and the Chamber of Secrets
# 4               4       5   Harry Potter and the Prisoner of Azkaban
# ...           ...     ...                                        ...
# 20063       20063   19996         Connecticut: In Words and Pictures
# 20064       20064   19997                    Through a Brazen Mirror
# 20065       20065   19998                         The Porcelain Dove
# 20066       20066   19999                      The Fall Of The Kings
# 20067       20067   20000                       Die Blume der Diener
#
#                                                   author  \
# 0                                           J.K. Rowling
# ...

# %%
df.shape
# Out:
# (20068, 24)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20068 entries, 0 to 20067
# Data columns (total 24 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Unnamed: 0          20068 non-null  int64
#  1   bookId              20068 non-null  int64
#  2   title               19509 non-null  object
#  3   author              19507 non-null  object
#  4   series              4279 non-null   object
#  5   description         17381 non-null  object
#  6   genres              19812 non-null  object
#  7   awards              3129 non-null   object
#  8   characters          4779 non-null   object
#  9   places              4040 non-null   object
#  10  isbn                17531 non-null  object
#  11  isbn13              19210 non-null  object
#  12  language            17289 non-null  object
#  13  first_publish_date  14591 non-null  object
#  14  publish_date        19022 non-null  object
# ...

# %%
df.isna().sum()
# Out:
# Unnamed: 0                0
# bookId                    0
# title                   559
# author                  561
# series                15789
# description            2687
# genres                  256
# awards                16939
# characters            15289
# places                16028
# isbn                   2537
# isbn13                  858
# language               2779
# first_publish_date     5477
# publish_date           1046
# num_pages              1640
# num_ratings             559
# num_reviews             559
# avg_rating              559
# rated_1                3430
# rated_2                3430
# rated_3                3430
# rated_4                3430
# rated_5                3430
# dtype: int64

# %%
df.dtypes
# Out:
# Unnamed: 0              int64
# bookId                  int64
# title                  object
# author                 object
# series                 object
# description            object
# genres                 object
# awards                 object
# characters             object
# places                 object
# isbn                   object
# isbn13                 object
# language               object
# first_publish_date     object
# publish_date           object
# num_pages             float64
# num_ratings           float64
# num_reviews           float64
# avg_rating            float64
# rated_1               float64
# rated_2               float64
# rated_3               float64
# rated_4               float64
# rated_5               float64
# dtype: object

# %%
x=df['title'].mode()[0]
df['title'].fillna(x,inplace=True)
y=df['author'].mode()[0]
df['author'].fillna(y,inplace=True)
z=df['series'].mode()[0]
df['series'].fillna(z,inplace=True)
h=df['description'].mode()[0]
df['description'].fillna(h,inplace=True)
i=df['genres'].mode()[0]
df['genres'].fillna(i,inplace=True)
k=df['awards'].mode()[0]
df['awards'].fillna(k,inplace=True)
g=df['characters'].mode()[0]
df['characters'].fillna(g,inplace=True)

# %%
a=df['places'].mode()[0]
df['places'].fillna(a,inplace=True)
b=df['isbn'].mode()[0]
df['isbn'].fillna(b,inplace=True)
c=df['isbn13'].mode()[0]
df['isbn'].fillna(c,inplace=True)
d=df['language'].mode()[0]
df['language'].fillna(d,inplace=True)
e=df['first_publish_date'].mode()[0]
df['first_publish_date'].fillna(e,inplace=True)
j=df['publish_date'].mode()[0]
df['publish_date'].fillna(j,inplace=True)
l=df['num_pages'].mean()
df['num_pages'].fillna(l,inplace=True)

# %%
m=df['num_ratings'].mean()
df['num_ratings'].fillna(m,inplace=True)
n=df['num_reviews'].mode()[0]
df['num_reviews'].fillna(n,inplace=True)
o=df['avg_rating'].mean()
df['avg_rating'].fillna(o,inplace=True)
p=df['rated_1'].mode()[0]
df['rated_1'].fillna(p,inplace=True)
q=df['rated_2'].mode()[0]
df['rated_2'].fillna(q,inplace=True)
r=df['rated_3'].mode()[0]
df['rated_3'].fillna(r,inplace=True)
s=df['rated_4'].mode()[0]
df['rated_4'].fillna(s,inplace=True)
t=df['rated_5'].mode()[0]
df['rated_5'].fillna(t,inplace=True)

# %%
df.drop(['Unnamed: 0','bookId'],axis=1,inplace=True)

# %% [markdown]
# WHAT IS THE NO OF TITLES,AUTHORS IN THE DATASET

# %%
n_titles = df['title'].nunique()
n_authors = df['author'].nunique()
n_language=df['language'].nunique()
print('Number of Titles in dataset:',n_titles)
print('Number of Authors in dataset:',n_authors)
print('Number of languages in dataset:',n_language)
# Out:
# Number of Titles in dataset: 16906
# Number of Authors in dataset: 11937
# Number of languages in dataset: 22

# %% [markdown]
# TOP 10 AUTHORS WITH HIGHEST BOOK RATING

# %%
author = pd.DataFrame(df.groupby('author')['avg_rating'].mean())
author_top_10 = author.sort_values(by='avg_rating',ascending=False).iloc[0:10]
author_top_10.head()
# Out:
#                                                     avg_rating
# author
# Augusta Rohrbach                                           5.0
# Valerie Wilson                                             5.0
# Nicholas P Stavroulakis                                    5.0
# Judie Olsson-Kenagy,Judie O. Kenagy,Kathleen Ol...         5.0
# Nicasio Urbina                                             5.0

# %% [markdown]
# ```
# # This is formatted as code
# ```
#
#  AUTHORS THAT HAVE LOW RATING COUNT

# %%
author_stats = df.groupby('author')['avg_rating'].agg(['count','mean'])
author_stats.head()
# Out:
#                                                     count  mean
# authors
# A.B. Yehoshua/Hillel Halkin                             2  3.60
# A.D.P. Briggs/Leo Tolstoy/Fyodor Dostoyevsky            1  3.76
# A.E. Cunningham/Harlan Ellison/Charles F. Mille...      1  4.15
# A.J. Jacobs                                             1  3.76
# A.M. Homes                                              1  3.28

# %%
sns.countplot(data=df,x='language')
sns.color_palette("flare", as_cmap=True)
plt.xticks(rotation=90)
plt.title('Number of books in each language')
plt.show()

# %% [markdown]
# ENG AND ENG US HAVE THE HIGHEST NO OF BOOKS

# %%
good_read['weighted_rating'] = 0.7*good_read['average_rating'] + 0.3*good_read['ratings_count']
top_10_books = good_read.sort_values(by='weighted_rating',ascending=False).iloc[0:10]

# %%
sns.barplot(data=count_author,x='author',y='count',palette='deep')
plt.xticks(rotation=90)
plt.title('10 Authors with most number of books')
plt.show()

# %%
biggest_book = good_read.sort_values(by='  num_pages',ascending=False).iloc[0:10]
biggest_book.head()
# Out:
#        bookID                                           title  \
# 6497    24520  The Complete Aubrey/Maturin Novels (5 Volumes)
# 6802    25587                            The Second World War
# 10906   44613          Remembrance of Things Past (Boxed Set)
# 6          10    Harry Potter Collection (Harry Potter  #1-6)
# 6822    25709                        Summa Theologica  5 Vols
#
#                                                  authors  average_rating  \
# 6497                                     Patrick O'Brian            4.70
# 6802                    Winston S. Churchill/John Keegan            4.45
# 10906  Marcel Proust/C.K. Scott Moncrieff/Frederick A...            4.34
# 6                                           J.K. Rowling            4.73
# 6822                                      Thomas Aquinas            4.12
#
#              isbn         isbn13 language_code    num_pages  ratings_count  \
# ...

# %%
+
+sns.barplot(data=biggest_book,x='title',y='  num_pages',palette='flare')
plt.xticks(rotation=90)
plt.title('Top 10 Biggest books')
plt.show()

# %%
from sklearn.preprocessing import LabelEncoder
code=LabelEncoder()
df['title']=code.fit_transform(df['title'])
df['author']=code.fit_transform(df['author'])
df['series']=code.fit_transform(df['series'])
df['description']=code.fit_transform(df['description'])
df['genres']=code.fit_transform(df['genres'])
df['awards']=code.fit_transform(df['awards'])
df['characters']=code.fit_transform(df['characters'])
df['places']=code.fit_transform(df['places'])
df['isbn']=code.fit_transform(df['isbn'])
df['isbn13']=code.fit_transform(df['isbn13'])
df['language']=code.fit_transform(df['language'])
df['first_publish_date']=code.fit_transform(df['first_publish_date'])
df['publish_date']=code.fit_transform(df['publish_date'])

# %%
df.corr()
# Out:
#                        title    author    series  description    genres  \
# title               1.000000  0.037374  0.149646     0.069020 -0.012571
# author              0.037374  1.000000 -0.020059     0.071356 -0.016297
# series              0.149646 -0.020059  1.000000     0.024488 -0.036486
# description         0.069020  0.071356  0.024488     1.000000 -0.102762
# genres             -0.012571 -0.016297 -0.036486    -0.102762  1.000000
# awards             -0.008331 -0.002644  0.007294    -0.013436  0.052979
# characters          0.016502  0.006867  0.075717     0.029586  0.014281
# places              0.016947  0.014551  0.034477     0.051966 -0.035243
# isbn               -0.083730 -0.011092 -0.008223     0.010635 -0.043055
# isbn13             -0.002684  0.053659 -0.006415     0.091479 -0.133531
# language           -0.065829  0.012522 -0.014889    -0.024502  0.044625
# first_publish_date -0.008758  0.002728  0.020032    -0.055230  0.101886
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.heatmap(df.corr(),annot=True,fmt=".2f",cmap="seismic")
# Out:
# <Axes: >

# %%
x=df
x
# Out:
#        title  author  series  description  genres  awards  characters  places  \
# 0       5481    4795     966        12337    2614     787         550     369
# 1       5482    4801     965        12441    2614     271        2007     371
# 2       5485    4801     960         5469    4510     894         551     503
# 3       5479    4795     962        10961    2616     893         552     370
# 4       5484    4801     963         4786    2616     269        2008     371
# ...      ...     ...     ...          ...     ...     ...         ...     ...
# 20063   2803    2595    1537          611       0     530         940     984
# 20064  15425    2566    1537         6206    2258     530         940     984
# 20065  14154    2565    1537         8524    2395     889         940     984
# 20066  12698    3177    2577         4928    2305    1608         940     984
# 20067   3429    2567    1537         3480    2258     530         940     984
#
# ...

# %%
from sklearn.cluster import KMeans
cls=[]
for i in range(1,15):
  data=KMeans(n_clusters=i,init='k-means++',random_state=42)
  data.fit(x)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# ...

# %%
from sklearn.cluster import KMeans
cls=[]
for i in range(1,15):
  data=KMeans(n_clusters=i,init='k-means++',random_state=42)
  data.fit(x)
  cls.append(data.inertia_)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# ...

# %%
plt.plot(range(1,15),cls)
plt.xlabel('Number of clusters')
plt.ylabel('Variance')
plt.title('Elbow points')
# Out:
# Text(0.5, 1.0, 'Elbow points')

# %%
from sklearn.cluster import KMeans
data1=KMeans(n_clusters=4,init='k-means++',random_state=42)
data1.fit(x)
y=data1.predict(x)
y
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# array([1, 1, 4, ..., 0, 0, 0], dtype=int32)

# %%
x['cluster']=y
x
# Out:
#        title  author  series  description  genres  awards  characters  places  \
# 0       5481    4795     966        12337    2614     787         550     369
# 1       5482    4801     965        12441    2614     271        2007     371
# 2       5485    4801     960         5469    4510     894         551     503
# 3       5479    4795     962        10961    2616     893         552     370
# 4       5484    4801     963         4786    2616     269        2008     371
# ...      ...     ...     ...          ...     ...     ...         ...     ...
# 20063   2803    2595    1537          611       0     530         940     984
# 20064  15425    2566    1537         6206    2258     530         940     984
# 20065  14154    2565    1537         8524    2395     889         940     984
# 20066  12698    3177    2577         4928    2305    1608         940     984
# 20067   3429    2567    1537         3480    2258     530         940     984
#
# ...

# %%
x1=df.iloc[:,:-1]
x1
# Out:
#        title  author  series  description  genres  awards  characters  places  \
# 0       5481    4795     966        12337    2614     787         550     369
# 1       5482    4801     965        12441    2614     271        2007     371
# 2       5485    4801     960         5469    4510     894         551     503
# 3       5479    4795     962        10961    2616     893         552     370
# 4       5484    4801     963         4786    2616     269        2008     371
# ...      ...     ...     ...          ...     ...     ...         ...     ...
# 20063   2803    2595    1537          611       0     530         940     984
# 20064  15425    2566    1537         6206    2258     530         940     984
# 20065  14154    2565    1537         8524    2395     889         940     984
# 20066  12698    3177    2577         4928    2305    1608         940     984
# 20067   3429    2567    1537         3480    2258     530         940     984
#
# ...

# %%
y1=df.iloc[:,-1]
y1
# Out:
# 0        1
# 1        1
# 2        4
# 3        1
# 4        1
#         ..
# 20063    0
# 20064    0
# 20065    0
# 20066    0
# 20067    0
# Name: cluster, Length: 20068, dtype: int32

# %%
from sklearn.model_selection import train_test_split
x1_train,x1_test,y1_train,y1_test=train_test_split(x1,y1,test_size=0.30,random_state=42)

# %%
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()
scaler.fit(x1_train)
x1_train=scaler.fit_transform(x1_train)
x1_test=scaler.fit_transform(x1_test)

# %%
from sklearn.svm import SVC
model=SVC()
model.fit(x1_train,y1_train)
y_pred=model.predict(x1_test)
y_pred
# Out:
# array([0, 0, 2, ..., 0, 0, 0], dtype=int32)

# %%
from sklearn.metrics import confusion_matrix,accuracy_score
cm=confusion_matrix(y1_test,y_pred)
cm
# Out:
# array([[5670,    0,    0,    0,    0],
#        [   0,   27,    0,    0,    0],
#        [  10,    0,  257,    0,    0],
#        [   0,    0,    1,   53,    0],
#        [   3,    0,    0,    0,    0]])

# %%
score=accuracy_score(y1_test,y_pred)
score
# Out:
# 0.9976748048496927
